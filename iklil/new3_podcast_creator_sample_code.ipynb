# %%
import os, sys
# import openai
from openai import AzureOpenAI
# !pip install python-dotenv
from dotenv import load_dotenv
import json
from openai import OpenAI

# %%
def APIKeyManager(model_type, key_path):
    
    load_dotenv(dotenv_path=key_path, override=True)
    if model_type=='azure':
        client = AzureOpenAI(
            api_version=os.environ["AZURE_API_VERSION"],
            azure_endpoint=os.environ["AZURE_OPENAI_ENDPOINT"],
            api_key=os.environ["AZURE_API_KEY"],
        )
        return client
    elif model_type=='fanar':
        client = OpenAI(base_url="https://api.fanar.qa/v1",api_key=os.environ["FANAR_API_KEY"],)
    elif model_type=='gemini':
        pass
    return client

# Load environment variables
model_type="azure"
deployment = APIKeyManager(model_type, "./azure.env")

# %%
class ImprovedPodcastOutlineGenerator:
    def __init__(self, deployment, model="gpt-4o"):
        self.model = model
        self.deployment = deployment

    def generate_outline(self, topic, information, host_persona, guest_persona, style="حواري", duration="30 دقيقة"):
        
        # Style-specific guidance
        style_prompts = {
            "حواري": """
أسلوب حواري:
- ركز على الحوار الطبيعي والتفاعل الشخصي بين المقدم والضيف
- أضف لحظات تداخل وتفاعل عفوي
- استخدم لغة ودية ومألوفة
- اجعل النقاش يبدو كمحادثة بين أصدقاء
- أكثر من الأسئلة الشخصية والتجارب الذاتية""",
            
            "تعليمي": """
أسلوب تعليمي:
- اهتم بتقديم المعلومات بطريقة منظمة ومفصلة
- استخدم أمثلة توضيحية وتشبيهات مفهومة
- اجعل الضيف يشرح المفاهيم خطوة بخطوة
- أضف أسئلة استيضاحية من المقدم
- ركز على الفهم العميق للموضوع مع الحفاظ على الطبيعية""",
            
            "ترفيهي": """
أسلوب ترفيهي:
- أضف عناصر مرحة وقصص شخصية طريفة
- استخدم الفكاهة المناسبة والتعليقات الخفيفة
- اجعل النقاش حيوياً ومليئاً بالطاقة
- أضف مواقف مضحكة أو غريبة مرتبطة بالموضوع
- ركز على الجانب الإنساني والممتع من الموضوع""",
            
            "تحليلي": """
أسلوب تحليلي:
- ركز على التحليل العميق والنقاش المتخصص
- استخدم بيانات وإحصائيات ومراجع علمية
- اطرح أسئلة تحليلية معقدة
- ناقش التحديات والحلول بتفصيل
- اجعل النقاش فكرياً ومتعمقاً مع الحفاظ على الوضوح"""
        }
        
        style_guidance = style_prompts.get(style, "حافظ على التوازن بين المحتوى والتفاعل")
        
        # Duration-specific guidance
        duration_guidance = ""
        if "45" in duration or "طويلة" in duration:
            duration_guidance = "نظراً لطول الحلقة، أضف المزيد من التفاصيل والأمثلة والنقاط الفرعية في كل قسم."
        elif "15" in duration or "قصيرة" in duration:
            duration_guidance = "نظراً لقصر الحلقة، ركز على النقاط الأساسية واجعل المحتوى مكثفاً ومباشراً."
        else:
            duration_guidance = "اجعل المحتوى متوازناً ومناسباً لحلقة متوسطة الطول."

        # Generic cultural integration
        cultural_integration = f"""
السياق الثقافي العربي المرتبط بأي موضوع:

ملاحظة مهمة: الأمثلة التالية هي للإرشاد فقط. يجب تطبيق نفس المبادئ على الموضوع الفعلي '{topic}' وليس استخدام الأمثلة حرفياً.

1. أمثال وحكم مرتبطة بالموضوع:
   - ابحث عن أمثال عربية ترتبط مباشرة بطبيعة الموضوع المطروح
   - مقولات مأثورة تتعلق بالمجال (مثل: العلم، التطور، الحكمة، الصبر، العمل)
   - حكم تتناسب مع روح الموضوع سواء كان تقني، ديني، سياسي، أو اجتماعي

2. مراجع إقليمية ومعاصرة:
   - تجارب المنطقة العربية أو الدول العربية في هذا المجال
   - مبادرات محلية أو خليجية أو عربية ذات صلة
   - شخصيات أو مؤسسات عربية رائدة في المجال
   - أحداث تاريخية أو معاصرة مرتبطة بالموضوع

3. التجارب المشتركة:
   - كيف يتفاعل المجتمع العربي مع هذا النوع من المواضيع
   - تحديات مشتركة نواجهها في المنطقة العربية
   - فرص مستقبلية للعالم العربي في هذا المجال
   - نقاط اهتمام مشتركة للجمهور العربي

4. الربط بالقيم العربية والإسلامية:
   - كيف يتماشى الموضوع مع القيم العربية والإسلامية (إن أمكن)
   - الفوائد المجتمعية من منظور ثقافي عربي
   - التحديات الأخلاقية أو الثقافية من منظور عربي
   - الموازنة بين التطور والحفاظ على الهوية
"""

        # Universal emotional arc
        emotional_arc = f"""
القوس العاطفي للحلقة (قابل للتطبيق على أي موضوع):

ملاحظة: هذا إطار عام يجب تطبيقه على الموضوع الفعلي وليس استخدام الأمثلة حرفياً.

1. البداية (حماس وترقب):
   - المقدم يبدأ بحماس طبيعي حسب شخصيته وعلاقته بالموضوع
   - تشويق للموضوع يناسب خلفية المستمعين العرب
   - ترقب لما سيشاركه الضيف من خبرات

2. الوسط (فضول وتعلم):
   - فضول متزايد من المقدم حول جوانب الموضوع
   - لحظات دهشة عند اكتشاف معلومات جديدة أو غير متوقعة
   - تفاعل إيجابي مع شروحات وتحليلات الضيف

3. التحدي (قلق أو تساؤل):
   - طرح تحديات أو مخاوف مشروعة حول الموضوع
   - نقاش حول الصعوبات أو المقاومة أو الجدل المحيط بالموضوع
   - تساؤلات أخلاقية أو ثقافية أو عملية حسب طبيعة الموضوع

4. الحل والفهم:
   - وصول لفهم أعمق أو منظور جديد مع الضيف
   - إيجاد حلول أو إجابات للتساؤلات المطروحة
   - تفاؤل حذر أو واقعي حسب طبيعة الموضوع

5. النهاية (إلهام ودعوة للعمل):
   - رسالة ملهمة تناسب الجمهور العربي وطبيعة الموضوع
   - خطوات عملية يمكن للمستمعين اتخاذها (إن أمكن)
   - تطلع للمستقبل والدور العربي في هذا المجال
"""

        prompt = f"""
أنت خبير بودكاست عربي متخصص في خلق محتوى تفاعلي أصيل وطبيعي لأي موضوع.

تحذير مهم: جميع الأمثلة والإرشادات المذكورة أدناه هي للتوجيه العام فقط. يجب تطبيق هذه المبادئ على الموضوع الفعلي المطلوب وهو '{topic}' وليس استخدام أي أمثلة حرفياً.

معلومات الحلقة:
الموضوع الفعلي: {topic}
المدة: {duration}
الأسلوب: {style}

{style_guidance}
{duration_guidance}

الشخصيات:
المقدم: {host_persona}
الضيف: {guest_persona}

متطلبات الحوار:
- اجعل كل شخصية تتحدث بأسلوبها المميز حسب خلفيتها
- أضف تفاعلات طبيعية ولحظات تداخل عفوي
- أدرج نقاط اختلاف صحي في وجهات النظر لإضافة أصالة
- اجعل المقدم يتعلم ويتفاعل مع معلومات الضيف الجديدة

{cultural_integration}

{emotional_arc}

المعلومات الأساسية للموضوع:
{information}

تذكر: كل المحتوى يجب أن يكون مرتبطاً بالموضوع الفعلي '{topic}' وليس أي موضوع آخر.

أنشئ مخططاً بصيغة JSON يتضمن العناصر التالية:

{{
    "episode_topic": "الموضوع الرئيسي للحلقة",
    "personas": {{
        "host": {{
            "name": "اسم المقدم",
            "background": "خلفية المقدم",
            "speaking_style": "أسلوب التحدث والنبرة"
        }},
        "guest": {{
            "name": "اسم الضيف", 
            "background": "خلفية الضيف",
            "speaking_style": "أسلوب التحدث والنبرة"
        }}
    }},
    "conversation_flow": {{
        "intro1": {{
            "opening_line": "الجملة الافتتاحية الفعلية للمقدم بالنص المطلوب",
            "podcast_introduction": "تعريف محدد بالبودكاست مرتبط بالموضوع",
            "episode_hook": "جملة تشويقية محددة عن موضوع الحلقة",
            "tone_guidance": "إرشادات النبرة المطلوبة",
            "spontaneity_elements": [
                "عبارات تلقائية محددة يقولها المقدم",
                "تعليقات شخصية مرتبطة بالموضوع"
            ]
        }},
        "intro2": {{
            "topic_introduction": "النص الفعلي لتقديم الموضوع",
            "guest_welcome": "النص الفعلي للترحيب بالضيف",
            "guest_bio_highlight": "تعريف محدد بخلفية الضيف مرتبط بالموضوع",
            "cultural_connections": [
                "ربط ثقافي محدد بالموضوع",
                "مرجع محلي أو إقليمي محدد"
            ],
            "transition_to_discussion": "النص الفعلي للانتقال إلى النقاش الرئيسي"
        }},
        "main_discussion": [
            {{
                "point_title": "عنوان النقطة الأولى",
                "personal_angle": "كيف ترتبط هذه النقطة بخلفية الشخصيات",
                "spontaneous_triggers": [
                    "محفزات تلقائية مرتبطة بهذه النقطة تحديداً",
                    "عبارات طبيعية للحديث عن هذا الجانب من الموضوع"
                ],
                "disagreement_points": "نقاط اختلاف أو جدل محتملة مرتبطة بهذه النقطة تحديداً",
                "cultural_references": [
                    "أمثال ومقولات مرتبطة بهذا الجانب من الموضوع",
                    "مراجع ثقافية محددة ذات صلة مباشرة"
                ],
                "natural_transitions": "عبارات انتقال طبيعية للنقطة التالية مرتبطة بالموضوع",
                "emotional_triggers": "محفزات عاطفية مرتبطة بهذا الجانب من الموضوع"
            }},
            {{
                "point_title": "عنوان النقطة الثانية",
                "personal_angle": "الربط الشخصي بالموضوع",
                "spontaneous_triggers": [
                    "محفزات تلقائية للنقطة الثانية",
                    "عبارات طبيعية مرتبطة بهذا الجانب"
                ],
                "disagreement_points": "نقاط جدل صحية",
                "cultural_references": [
                    "مراجع ثقافية ذات صلة",
                    "تجارب مشتركة"
                ],
                "natural_transitions": "انتقالات سلسة",
                "emotional_triggers": "محفزات عاطفية"
            }},
            {{
                "point_title": "عنوان النقطة الثالثة",
                "personal_angle": "زاوية شخصية للموضوع",
                "spontaneous_triggers": [
                    "محفزات تلقائية للنقطة الثالثة",
                    "عبارات طبيعية لهذا الجانب"
                ],
                "disagreement_points": "نقاط اختلاف بناءة",
                "cultural_references": [
                    "حكم ومأثورات",
                    "قصص تراثية"
                ],
                "natural_transitions": "عبارات ربط طبيعية",
                "emotional_triggers": "لحظات تأثر طبيعية"
            }}
        ],
        "spontaneous_moments": {{
            "natural_interruptions": [
                "نقاط تداخل طبيعية مرتبطة بالموضوع",
                "لحظات مقاطعة إيجابية حول جوانب محددة من الموضوع"
            ],
            "emotional_reactions": [
                "محفزات عاطفية مرتبطة بالموضوع المطروح",
                "لحظات تأثر حقيقية حول جوانب الموضوع"
            ],
            "personal_stories": [
                "قصص شخصية مرتبطة بالموضوع حسب خلفية كل شخصية",
                "تجارب ذاتية متعلقة بالموضوع المحدد"
            ],
            "humorous_moments": [
                "لحظات طريفة مرتبطة بالموضوع",
                "تعليقات مرحة حول جوانب من الموضوع"
            ]
        }},
        "personality_interactions": {{
            "host_strengths": "نقاط قوة المقدم في الحوار",
            "guest_expertise": "مجالات خبرة الضيف",
            "natural_chemistry": "كيف تتفاعل الشخصيتان طبيعياً",
            "tension_points": "نقاط توتر صحية للحوار",
            "collaboration_moments": "لحظات تعاون وتفاهم"
        }},
        "closing": {{
            "conclusion": {{
                "main_takeaways": "النقاط الرئيسية المحددة التي يجب تلخيصها",
                "guest_final_message": "الرسالة الختامية المحددة للضيف",
                "host_closing_thoughts": "أفكار المقدم الختامية المحددة",
                "summary_tone": "نبرة التلخيص المطلوبة"
            }},
            "outro": {{
                "guest_appreciation": "النص الفعلي لشكر الضيف",
                "audience_thanks": "النص الفعلي لشكر المستمعين",
                "call_to_action": "الدعوة المحددة للتفاعل",
                "next_episode_teaser": "التشويق المحدد للحلقة القادمة",
                "final_goodbye": "النص الفعلي للوداع",
                "engagement_question": "السؤال المحدد للجمهور"
            }}
        }}
    }},
    "cultural_context": {{
        "proverbs_sayings": [
            "أمثال وحكم مرتبطة مباشرة بالموضوع المطروح",
            "مقولات مأثورة ذات صلة بالموضوع المحدد"
        ],
        "regional_references": [
            "مراجع محلية وإقليمية متعلقة بالموضوع",
            "تجارب عربية أو محلية مرتبطة بالموضوع"
        ],
        "shared_experiences": [
            "تجارب جماعية عربية مرتبطة بالموضوع",
            "ذكريات أو مواقف مشتركة متعلقة بالموضوع"
        ],
        "contemporary_relevance": [
            "أحداث جارية مرتبطة بالموضوع",
            "تطورات حديثة في المجال المطروح"
        ]
    }},
    "language_style": {{
        "formality_level": "مستوى الرسمية في اللغة",
        "dialect_touches": "لمسات لهجية خفيفة مناسبة",
        "vocabulary_richness": "ثراء المفردات المستخدمة",
        "sentence_variety": "تنويع في طول وتركيب الجمل"
    }},
    "technical_notes": {{
        "pacing_guidance": "إرشادات حول إيقاع الحديث",
        "pause_points": "نقاط توقف طبيعية",
        "emphasis_moments": "لحظات تأكيد وتشديد",
        "background_music_cues": "إشارات للموسيقى التصويرية"
    }}
}}

مهم جداً - متطلبات المحتوى:
- لا تكتب أوصافاً عامة مثل "ترحيب عام" أو "تقديم الموضوع"
- اكتب المحتوى الفعلي والنصوص المحددة التي سيقولها المقدم والضيف
- كل قيمة يجب أن تحتوي على نص حقيقي وليس وصفاً لما يجب فعله
- استخدم أسماء الشخصيات الفعلية (أحمد، نور) في النصوص
- اجعل كل محتوى مرتبطاً مباشرة بموضوع {topic}
- أرجع المخطط بصيغة JSON صحيحة فقط
- لا تضع علامات ```json في البداية أو ``` في النهاية
- لا تكتب أي نص إضافي قبل أو بعد JSON

مثال على ما هو مطلوب:
بدلاً من: "ترحيب عام بالمستمعين"
اكتب: "أهلاً وسهلاً بكم في حلقة جديدة من بودكاست التقنية والمستقبل، أنا أحمد المصري معكم اليوم"

بدلاً من: "تقديم الموضوع"
اكتب: "اليوم سنتحدث عن {topic}، هذا الموضوع المذهل الذي قد يغير حياتنا كلياً"
"""
        
        response = self.deployment.chat.completions.create(
            model=self.model,
            messages=[
                {"role": "system", "content": f"أنت خبير في تصميم البودكاست العربية وتخصص في خلق محتوى طبيعي وتلقائي باللغة العربية الفصحى. الأسلوب المطلوب: {style}"},
                {"role": "user", "content": prompt}
            ],
            temperature=0.7
        )
        
        return response.choices[0].message.content

    def generate_outline_with_style(self, topic, information, host_persona, guest_persona, style="حواري", duration="30 دقيقة"):
        """
        Generate outline with specific style considerations
        Styles: حواري (conversational), تعليمي (educational), ترفيهي (entertaining), تحليلي (analytical)
        """
        # Now this method just calls the main method which already handles style
        return self.generate_outline(topic, information, host_persona, guest_persona, style, duration)

    def validate_outline(self, outline_json):
        """
        Validate that the generated outline contains all required elements
        """
        required_keys = [
            "episode_topic", "personas", "conversation_flow", 
            "cultural_context", "language_style", "technical_notes"
        ]
        
        try:
            import json
            outline = json.loads(outline_json)
            
            missing_keys = []
            for key in required_keys:
                if key not in outline:
                    missing_keys.append(key)
            
            if missing_keys:
                return False, f"Missing required keys: {missing_keys}"
            
            return True, "Outline validation successful"
            
        except json.JSONDecodeError:
            return False, "Invalid JSON format"

# %%
# # ---------------------------------------------------------------
# #  New sample run: العنوسة في المجتمع العربي episode (entertaining style)
# # ---------------------------------------------------------------

# outline_generator = ImprovedPodcastOutlineGenerator(deployment, "gpt-4o")

# topic = "ظاهرة العنوسة في المجتمع العربي: أسباب وحلول"

# information = (
#    "ظاهرة العنوسة تشهد ارتفاعاً ملحوظاً في المجتمعات العربية، حيث تشير الإحصائيات إلى أن 30% من النساء في دول الخليج "
#    "و 25% من الرجال تجاوزوا سن الثلاثين دون زواج، مقارنة بـ 15% قبل عقدين. "
#    "الأسباب متعددة تشمل ارتفاع تكاليف الزواج والسكن، تغير الأولويات المهنية والتعليمية، صعوبة التوافق بين الشريكين، "
#    "وتأثير وسائل التواصل الاجتماعي على توقعات الشباب من الزواج. "
#    "العوامل الاقتصادية تلعب دوراً كبيراً حيث تصل تكلفة الزواج في بعض الدول العربية إلى 200 ألف دولار شاملة المهر والحفل والسكن. "
#    "التغيرات الاجتماعية مثل دخول المرأة سوق العمل بقوة، السفر للدراسة، وتقبل المجتمع للعزوبية أكثر من الماضي "
#    "أدت لتأخير قرارات الزواج. "
#    "الحلول المقترحة تتضمن برامج التيسير الحكومية، منصات التعارف المحترمة، ورش التأهيل للزواج، "
#    "وحملات توعية لتغيير النظرة المجتمعية حول تكاليف الزواج والعمر المناسب له."
# )

# host_persona = """فيصل العتيبي - العمر: 38
# المهنة/الخلفية: إعلامي ومقدم برامج اجتماعية من الرياض، متزوج وأب لثلاثة أطفال
# الشخصية: دبلوماسي، مرح، يجيد التعامل مع المواضيع الحساسة بخفة دم، يحب سرد القصص الشخصية
# OCEAN: انفتاح عالٍ، ضمير عالٍ، انبساط عالٍ جداً، وداعة عالية، عصابية منخفضة
# أسلوب التحدث: يستخدم الفكاهة لكسر الحرج، يشارك تجاربه الشخصية، يطرح أسئلة مباشرة لكن بلطف"""

# guest_persona = """د. نورا السالم - العمر: 42
# المهنة/الخلفية: استشارية علم اجتماع وخبيرة في قضايا المرأة والأسرة من بيروت، عزباء بالاختيار
# الشخصية: ذكية، صريحة، واثقة من نفسها، تملك حس دعابة عالي، لا تخجل من مناقشة المواضيع الشائكة
# OCEAN: انفتاح عالٍ جداً، ضمير عالٍ، انبساط متوسط، وداعة متوسطة، عصابية منخفضة
# أسلوب التحدث: تحليل علمي مع لمسة شخصية، تستخدم البيانات والإحصائيات، تتحدث بصراحة عن تجربتها"""

# # entertaining style
# outline_text = outline_generator.generate_outline(
#    topic,
#    information,
#    host_persona,
#    guest_persona,
#    style="ترفيهي"
# )

# print("Generated Outline:\n", outline_text)




# ---------------------------------------------------------------
#  New sample run: AI in Education episode (entertaining style)
# ---------------------------------------------------------------

outline_generator = ImprovedPodcastOutlineGenerator(deployment, "gpt-4o")

topic = "الذكاء الاصطناعي في التعليم: كيف يغيّر مستقبل التعلّم؟"

information = (
    "يتوقع أن يتجاوز حجم سوق تقنيات الذكاء الاصطناعي في التعليم عالمياً 30 مليار دولار بحلول 2030، "
    "بنمو سنوي يقارب 30٪. في العالم العربي، تبنت السعودية منصة «مدرستي» التي تستخدم التحليلات التعلّمية "
    "لتخصيص الدروس، فيما أطلقت الإمارات استراتيجية «مدرسة المستقبل» المبنية على مساعدات تدريس ذكية. "
    "التطبيقات تشمل أنظمة التعلّم التكيّفي، تصحيح الواجبات آلياً، وتوليد محتوى تعليمي فوري. "
    "الفوائد المحتملة: تحسين استيعاب الطلاب، تخفيف عبء المعلم الإداري، وتوفير تعليم شخصي لذوي الإعاقة. "
    "لكن التحديات تتضمن مخاوف الخصوصية، التحيز الخوارزمي، فجوة المهارات الرقمية بين المعلمين، "
    "والتكلفة الأولية العالية لتبنّي الحلول المتقدمة. دراسات اليونسكو 2024 تشير إلى أن 42٪ من المدارس "
    "في المنطقة لم تجهّز بعد بالبنية التحتية التقنية الكافية، ما يجعل تكافؤ الفرص أحد أبرز القضايا."
)

host_persona = """مريم أبو زهرة - العمر: 24
المهنة/الخلفية: طالبة صحافة وإذاعية ناشئة من القاهرة، تغطي قصص التعليم والتحول الرقمي
الشخصية: حماسية، فضولية، تحب طرح الأسئلة البسيطة التي تمس حياة الطلاب
OCEAN: انفتاح عالٍ، ضمير متوسط، انبساط عالٍ، وداعة عالية، عصابية متوسطة
أسلوب التحدث: لغة سهلة، قصص طلابية، تعليقات مرحة خفيفة"""

guest_persona = """د. ليلى الخالدي - العمر: 45
المهنة/الخلفية: أستاذة دراسات مستقبلية وتقنيات تعليم في جامعة قطر، باحثة في استخدام الذكاء الاصطناعي للتعلّم
الشخصية: هادئة، متفائلة، تركّز على الأثر المجتمعي للتقنية
OCEAN: انفتاح عالٍ جداً، ضمير عالٍ، انبساط متوسط، وداعة عالية، عصابية منخفضة
أسلوب التحدث: شروح مبسّطة، أمثلة واقعية، اقتباسات علمية، تربط التقنية بتنمية المهارات"""

# entertaining style
outline_text = outline_generator.generate_outline(
    topic,
    information,
    host_persona,
    guest_persona,
    style="ترفيهي"
)

print("Generated Outline:\n", outline_text)
# Out:
# Generated Outline:
#  {
#     "episode_topic": "الذكاء الاصطناعي في التعليم: كيف يغيّر مستقبل التعلّم؟",
#     "personas": {
#         "host": {
#             "name": "مريم أبو زهرة",
#             "background": "طالبة صحافة وإذاعية ناشئة من القاهرة، تغطي قصص التعليم والتحول الرقمي",
#             "speaking_style": "لغة سهلة ومباشرة مع قصص طلابية وتعليقات مرحة خفيفة"
#         },
#         "guest": {
#             "name": "د. ليلى الخالدي",
#             "background": "أستاذة دراسات مستقبلية وتقنيات تعليم في جامعة قطر، باحثة في استخدام الذكاء الاصطناعي للتعلّم",
#             "speaking_style": "شروح مبسّطة مع أمثلة واقعية واقتباسات علمية تربط التقنية بتنمية المهارات"
#         }
#     },
#     "conversation_flow": {
#         "intro1": {
#             "opening_line": "مرحباً وأهلاً بكم في بودكاست \"تعلّم المستقبل\"! أنا مريم أبو زهرة، واليوم لدينا موضوع شيق جداً سيجعلكم تفكرون في المدرسة بشكل مختلف تماماً.",
#             "podcast_introduction": "في هذا البودكاست، نناقش كل ما يخص التعليم والتكنولوجيا، وكيف يمكن أن تغيّر حياتنا. اليوم سنتحدث عن الذكاء الاصطناعي، هذا المارد التقني الذي قد يصبح أفضل صديق للطلاب والمعلمين.",
#             "episode_hook": "هل تخيلتم يوماً أن المعلم الخاص بكم قد يكون روبوتاً؟ أو أن الواجبات تُصحَّح بدون تدخل بشري؟ هذا ما سنتحدث عنه اليوم!",
#             "tone_guidance": "نبرة حماسية ومفعمة بالطاقة مع لمسات من الفكاهة لجعل الموضوع جذاباً وسهل الفهم.",
#             "spontaneity_elements": [
#                 "أوه، تخيّلوا لو أن الذكاء الاصطناعي يعلمني كيف أحل معادلات الرياضيات! كنت سأكون نابغة الآن!",
#                 "بصراحة، فكرة الذكاء الاصطناعي في التعليم تجعلني أتحمس وأقلق بنفس الوقت. ماذا عنكم؟"
#             ]
#         },
#         "intro2": {
#             "topic_introduction": "موضوعنا اليوم هو كيف يمكن للذكاء الاصطناعي أن يغيّر مستقبل التعليم. هل نحن مستعدون لهذا التحوّل؟ وهل يمكن أن يحل الذكاء الاصطناعي محل المعلمين؟",
#             "guest_welcome": "معنا اليوم خبيرة مميزة جداً، د. ليلى الخالدي، التي ستأخذنا في رحلة لفهم كيف يمكن للتكنولوجيا أن تصبح جزءاً من فصولنا الدراسية.",
#             "guest_bio_highlight": "د. ليلى متخصصة في الدراسات المستقبلية وتقنيات التعليم، وقد عملت على مشاريع بحثية رائعة في هذا المجال. أهلاً بك د. ليلى!",
#             "cultural_connections": [
#                 "في دول مثل السعودية والإمارات، هناك مبادرات تعليمية مذهلة تعتمد على الذكاء الاصطناعي، مثل منصة مدرستي واستراتيجية مدرسة المستقبل.",
#                 "كما يقول المثل العربي: 'العلم في الصغر كالنقش على الحجر'، فهل سيصبح النقش اليوم رقمياً بدل الحجر؟"
#             ],
#             "transition_to_discussion": "لنبدأ الآن باستكشاف كيف يمكن لهذه التقنية أن تغيّر طريقة تعلّمنا."
#         },
#         "main_discussion": [
#             {
#                 "point_title": "كيف يعمل الذكاء الاصطناعي في التعليم؟",
#                 "personal_angle": "مريم: بصراحة، كنت دائماً أتساءل كيف يمكن للذكاء الاصطناعي أن يعرف ما أحتاجه كطالبة. هل يقرأ أفكاري؟",
#                 "spontaneous_triggers": [
#                     "د. ليلى: لا، لا يقرأ أفكارك، ولكنه يعتمد على تحليل بياناتك الدراسية السابقة.",
#                     "مريم: أوه، هذا يشبه أن يكون لي مدرب شخصي طوال الوقت!"
#                 ],
#                 "disagreement_points": "مريم: لكن، ألا يمكن أن يصبح هذا مخيفاً؟ أعني، ماذا عن خصوصيتي؟",
#                 "cultural_references": [
#                     "في الإمارات، يستخدمون مساعدات ذكية لتخصيص الدروس للطلاب، وهذا يشبه فكرة 'التعليم الشخصي' التي قد تكون مستقبلنا.",
#                     "كما نعلم جميعاً، التعليم كان دائماً جزءاً مهماً من تراثنا العربي، فهل هذا التطور يهدد الهوية التقليدية للتعليم؟"
#                 ],
#                 "natural_transitions": "مريم: حسناً، هذا رائع، لكن ماذا عن المعلمين؟ هل سيشعرون بأنهم مُهددون؟",
#                 "emotional_triggers": "مريم: تخيّلت للتو أنني أتعلم على يد روبوت! شعور غريب لكنه مثير!"
#             },
#             {
#                 "point_title": "كيف يمكن أن يساعد الذكاء الاصطناعي الطلاب ذوي الإعاقة؟",
#                 "personal_angle": "د. ليلى: أنا شخصياً أؤمن بأن التكنولوجيا يمكن أن تكون أداة عظيمة لتحقيق تكافؤ الفرص للجميع.",
#                 "spontaneous_triggers": [
#                     "مريم: هذا مذهل! تخيّلوا أن طالباً كفيفاً يمكنه قراءة الكتب بسهولة من خلال الذكاء الاصطناعي.",
#                     "د. ليلى: تماماً، التطبيقات مثل قارئات النصوص الذكية تُحدث فرقاً كبيراً."
#                 ],
#                 "disagreement_points": "مريم: لكن، هل يمكن أن تكون هذه التقنية مكلفة جداً بحيث يصعب على المدارس توفيرها للجميع؟",
#                 "cultural_references": [
#                     "في تقرير اليونسكو، أُشير إلى أن 42٪ من المدارس في المنطقة العربية تفتقر للبنية التحتية اللازمة للتكنولوجيا.",
#                     "كما يقولون، 'من جد وجد ومن زرع حصد'، فهل يمكن للمدارس العربية أن تحصد ثمار هذا الاستثمار؟"
#                 ],
#                 "natural_transitions": "مريم: إذاً، هل يمكن للذكاء الاصطناعي أن يكون الحل لتحديات التعليم في المناطق النائية؟",
#                 "emotional_triggers": "مريم: شعرت بالدفء عندما تخيّلت أن كل طالب يحصل على فرصة عادلة للتعلم."
#             },
#             {
#                 "point_title": "التحديات الأخلاقية والثقافية للذكاء الاصطناعي في التعليم",
#                 "personal_angle": "مريم: بصراحة، أشعر ببعض القلق. هل يمكن أن يؤثر الذكاء الاصطناعي على قيمنا وثقافتنا؟",
#                 "spontaneous_triggers": [
#                     "د. ليلى: هذا سؤال مهم جداً. التحديات الأخلاقية مثل التحيز الخوارزمي تحتاج إلى حلول مستدامة.",
#                     "مريم: تخيلوا أن النظام يقرر أنني لا أستحق درجة معينة بسبب خطأ في البرمجة!"
#                 ],
#                 "disagreement_points": "مريم: لكن، ألا يمكننا وضع قيود لضمان أن الذكاء الاصطناعي يبقى أداة وليس المتحكم؟",
#                 "cultural_references": [
#                     "في ثقافتنا العربية، التعليم دائماً كان مرتبطاً بالقيم الإنسانية، فكيف يمكننا أن نحافظ على هذا الجانب مع دخول التقنية؟",
#                     "كما يقول المثل: 'العلم نور'، فهل يمكن للذكاء الاصطناعي أن يُطفئ هذا النور؟"
#                 ],
#                 "natural_transitions": "مريم: حسناً، ربما علينا أن نفكر في كيفية استخدام الذكاء الاصطناعي بحذر.",
#                 "emotional_triggers": "مريم: شعرت بقليل من التوتر عندما فكرت في تأثير التقنية على الطريقة التي نتواصل بها كبشر."
#             }
#         ],
#         "spontaneous_moments": {
#             "natural_interruptions": [
#                 "مريم تقاطع د. ليلى قائلة: 'لكن، هل يمكن أن يشعر الطلاب بالكسل مع كل هذا الدعم التقني؟'",
#                 "د. ليلى تضحك وتقول: 'هذا سؤال شائع، لكن الذكاء الاصطناعي يعزز المهارات ولا يحل محلها.'"
#             ],
#             "emotional_reactions": [
#                 "مريم تقول: 'هذا يجعلني أفكر في كل التحديات التي قد تواجهنا كطلاب.'",
#                 "د. ليلى تقول: 'أحياناً أشعر بالتفاؤل الكبير عندما أرى كيف يمكن للتكنولوجيا أن تخدم الإنسانية.'"
#             ],
#             "personal_stories": [
#                 "مريم تشارك: 'كنت أواجه صعوبة في الرياضيات، تخيّلت لو كان لدي مساعد ذكي وقتها!'",
#                 "د. ليلى تقول: 'أحد الطلاب الذين عملت معهم استطاع أن يتجاوز مشاكله بفضل الذكاء الاصطناعي.'"
#             ],
#             "humorous_moments": [
#                 "مريم تمزح: 'لو علمني الروبوت كيف أكتب مقالاتي، سأصبح أشهر صحفية في العالم العربي!'",
#                 "د. ليلى تقول: 'لكن، هل سيطلب الروبوت زيادة راتب إذا عمل بجد؟!'"
#             ]
#         },
#         "personality_interactions": {
#             "host_strengths": "حماس مريم يجعل النقاش ممتعاً وقريباً من الطلاب الشباب.",
#             "guest_expertise": "د. ليلى تقدم شروحات مبسطة ودقيقة تجعل الموضوع سهل الفهم.",
#             "natural_chemistry": "التفاعل بين مريم ود. ليلى مليء بالطاقة والأسئلة الفضولية.",
#             "tension_points": "مريم تقلق بشأن الخصوصية بينما د. ليلى تؤكد على الفوائد.",
#             "collaboration_moments": "مريم ود. ليلى يتفقان على ضرورة التحوّل الرقمي بحذر."
#         },
#         "closing": {
#             "conclusion": {
#                 "main_takeaways": "الذكاء الاصطناعي يمكن أن يغير الطريقة التي نتعلم بها، لكن علينا أن نستخدمه بحكمة.",
#                 "guest_final_message": "د. ليلى: 'التكنولوجيا ليست عدواً، بل فرصة لنقل التعليم إلى مستوى جديد.'",
#                 "host_closing_thoughts": "مريم: 'بصراحة، أشعر بالتفاؤل، لكن لا ننسى أن الإنسان هو الأساس.'",
#                 "summary_tone": "نبرة متفائلة مع دعوة للتوازن."
#             },
#             "outro": {
#                 "guest_appreciation": "مريم: 'شكراً جزيلاً د. ليلى على هذه الأفكار الرائعة والنقاش الممتع!'",
#                 "audience_thanks": "مريم: 'شكراً لكل مستمعينا الأعزاء على وقتكم واهتمامكم.'",
#                 "call_to_action": "مريم: 'لا تنسوا مشاركتنا أفكاركم حول الذكاء الاصطناعي في التعليم عبر التعليقات.'",
#                 "next_episode_teaser": "مريم: 'في الحلقة القادمة، سنتحدث عن كيفية بناء المهارات المستقبلية في عصر التكنولوجيا.'",
#                 "final_goodbye": "مريم: 'إلى اللقاء، دمتم بخير وفضول مستمر!'",
#                 "engagement_question": "مريم: 'هل تعتقدون أن الذكاء الاصطناعي يمكن أن يحل محل المعلمين يوماً؟'"
#             }
#         }
#     },
#     "cultural_context": {
#         "proverbs_sayings": [
#             "كما يقول المثل: 'العلم نور'، لكن هل سيصبح هذا النور رقمياً بالكامل؟",
#             "كما يقولون: 'من تعلم صغيراً، استفاد كبيراً.'"
#         ],
#         "regional_references": [
#             "السعودية تبنت منصة مدرستي لتخصيص التعليم باستخدام الذكاء الاصطناعي.",
#             "الإمارات تعمل على تطوير استراتيجية مدرسة المستقبل بفضل التقنيات الذكية."
#         ],
#         "shared_experiences": [
#             "في المنطقة العربية، التحديات تشمل نقص البنية التحتية التقنية.",
#             "الكثير من الطلاب العرب يواجهون صعوبات في الوصول إلى التعليم المتقدم."
#         ],
#         "contemporary_relevance": [
#             "دراسات اليونسكو تشير إلى أن العديد من المدارس العربية تحتاج إلى تحسينات تقنية.",
#             "التوجه نحو التعليم الرقمي أصبح جزءاً مهماً من استراتيجيات الدول العربية."
#         ]
#     },
#     "language_style": {
#         "formality_level": "غير رسمي ومناسب للشباب مع نبرة حيوية.",
#         "dialect_touches": "لمسات مصرية خفيفة من المقدم.",
#         "vocabulary_richness": "مفردات تقنية مبسطة مع لغة سهلة الفهم.",
#         "sentence_variety": "جمل قصيرة ومتوسطة الطول لتسهيل الفهم."
#     },
#     "technical_notes": {
#         "pacing_guidance": "حافظ على إيقاع سريع وممتع مع لحظات توقف للتأكيد.",
#         "pause_points": "توقف قصير بعد النقاط المهمة للسماح بالتفكير.",
#         "emphasis_moments": "تشديد على الفوائد والتحديات الرئيسية للذكاء الاصطناعي.",
#         "background_music_cues": "موسيقى هادئة في البداية وموسيقى ديناميكية عند الانتقال بين النقاط."
#     }
# }

# %%
class MSADialogueEnhancer:
    def __init__(self, deployment, model="gpt-4o"):
        self.model = model
        self.deployment = deployment

    def enhance_section(self, section_name, content, criteria, complexity="بسيط", episode_topic="", style_example=None):
        
        complexity_guidance = {
            "بسيط": "استخدم لغة بسيطة ومفهومة للجمهور العام، تجنب المصطلحات المعقدة",
            "متوسط": "امزج بين البساطة والتعمق، استخدم مصطلحات تقنية مع الشرح",
            "معقد": "استخدم مصطلحات متخصصة ومفاهيم متقدمة مع شرح تفصيلي"
        }
        
        # Topic context to avoid confusion
        topic_context = f"""
تذكر أن موضوع الحلقة هو: {episode_topic}
يجب أن يكون كل المحتوى مرتبطاً بهذا الموضوع تحديداً وليس أي موضوع آخر.
"""
        
        if style_example:
            prompt = f"""
هذا مثال على أسلوب الحوار المطلوب:
{style_example}

{topic_context}

بناءً على القسم التالي من البودكاست، قم بتطويره وتحسينه حسب المعايير التالية: {criteria}

مستوى التعقيد المطلوب: {complexity}
{complexity_guidance.get(complexity, '')}

القسم: {section_name}
المحتوى: {content}

المطلوب:
- تأكد أن المحتوى يتعلق بموضوع: {episode_topic}
- اكتب نصاً تفاعلياً وجذاباً باللغة العربية الفصحى
- أضف حشو طبيعي متوسط مثل: يعني، طبعاً، بصراحة، اممم، اههه
- استخدم 70% فصحى و 30% لمسات خليجية خفيفة
- أدرج مراجع ثقافية عند الحاجة
- اجعل النص طبيعياً وتلقائياً
"""
        else:
            prompt = f"""
{topic_context}

بناءً على القسم التالي من البودكاست، قم بتطويره وتحسينه حسب المعايير التالية: {criteria}

مستوى التعقيد المطلوب: {complexity}
{complexity_guidance.get(complexity, '')}

القسم: {section_name}
المحتوى: {content}

المطلوب:
- تأكد أن المحتوى يتعلق بموضوع: {episode_topic} فقط
- اكتب نصاً تفاعلياً وجذاباً باللغة العربية الفصحى
- أضف حشو طبيعي متوسط مثل: يعني، طبعاً، بصراحة، اممم، اههه، واو
- استخدم 70% فصحى و 30% لمسات خليجية خفيفة (مثل: شلون، وش رايك، الله يعطيك العافية)
- أدرج مراجع ثقافية مرتبطة بالموضوع عند الحاجة
- اجعل النص طبيعياً وتلقائياً
"""
        
        response = self.deployment.chat.completions.create(
            model=self.model,
            messages=[
                {"role": "system", "content": "أنت كاتب سيناريو بودكاست محترف متخصص في المحتوى العربي الطبيعي والتلقائي."},
                {"role": "user", "content": prompt}
            ],
            temperature=0.8
        )
        return response.choices[0].message.content

# %%
class MSASpontaneousDialogueGenerator:
    def __init__(self, deployment, model="gpt-4o"):
        self.model = model
        self.deployment = deployment
    
    def generate_dialogue(self, section, section_content, host_persona, guest_persona, complexity="بسيط", style="تعليمي", episode_topic="", style_example=None):
        
        complexity_guidance = {
            "بسيط": "اجعل الشرح بسيطاً ومفهوماً للجمهور العام",
            "متوسط": "امزج بين البساطة والعمق، أضف تفاصيل تقنية مع الشرح",
            "معقد": "استخدم مصطلحات متخصصة ونقاش متعمق مع شرح تفصيلي"
        }
        
        style_guidance = {
            "حواري": "ركز على الحوار الطبيعي والتفاعل الشخصي، أضف لحظات تداخل وتفاعل عفوي",
            "تعليمي": "اهتم بتقديم المعلومات بطريقة منظمة ومفصلة، استخدم أمثلة توضيحية",
            "ترفيهي": "أضف عناصر مرحة وقصص شخصية طريفة، استخدم الفكاهة المناسبة",
            "تحليلي": "ركز على التحليل العميق والنقاش المتخصص، استخدم بيانات وإحصائيات"
        }
        
        # MSA fillers for natural conversation
        fillers_guide = """
استخدم حشو المحادثة الطبيعي بكثافة متوسطة:
- تفكير: اممم، اههه، يعني كيف أقول، خلاص
- تأكيد: طبعاً، تماماً، بالضبط، صحيح
- تردد: يعنييييي، يعني، اه ما أدري، شوف
- انفعال: واو، يا الله، ما شاء الله، الله يعطيك العافية
- ربط: بس، لكن، وبعدين، يا أخي، اسمع
- خليجي خفيف: شلون، وش رايك، زين، ماشي الحال
"""
        
        # Topic context to avoid confusion
        topic_context = f"""
تذكر أن موضوع الحلقة هو: {episode_topic}
يجب أن يكون كل الحوار مرتبطاً بهذا الموضوع تحديداً وليس أي موضوع آخر.
"""
        
        if style_example:
            prompt = f"""
هذا مثال على أسلوب الحوار المطلوب:
{style_example}

{topic_context}

حول القسم التالي إلى حوار تلقائي وطبيعي بين المقدم والضيف:

المقدم: {host_persona}
الضيف: {guest_persona}

القسم: {section}
المحتوى: {section_content}

الأسلوب المطلوب: {style}
{style_guidance.get(style, '')}

مستوى التعقيد: {complexity}
{complexity_guidance.get(complexity, '')}

{fillers_guide}

متطلبات الحوار:
- تأكد أن الحوار يدور حول موضوع: {episode_topic}
- استخدم أسماء الشخصيات الفعلية في الحوار
- اجعل كل شخصية تتحدث بأسلوبها المميز
- أضف تفاعلات طبيعية: <happy>, <surprise>, <overlap> (فقط عند الحاجة)
- استخدم 70% فصحى و 30% لمسات خليجية
- أدرج مراجع ثقافية مرتبطة بالموضوع
- اجعل الحوار يتكيف مع الموضوع
- أضف فواصل طبيعية [pause: 2s] عند الحاجة
- ابدأ كل جملة بـ المقدم: أو الضيف:
"""
        else:
            prompt = f"""
{topic_context}

حول القسم التالي إلى حوار تلقائي وطبيعي بين المقدم والضيف باللغة العربية الفصحى:

المقدم: {host_persona}
الضيف: {guest_persona}

القسم: {section}
المحتوى: {section_content}

الأسلوب المطلوب: {style}
{style_guidance.get(style, '')}

مستوى التعقيد: {complexity}
{complexity_guidance.get(complexity, '')}

{fillers_guide}

متطلبات الحوار:
- تأكد أن الحوار يدور حول موضوع: {episode_topic} فقط
- استخدم أسماء الشخصيات الفعلية (أحمد، نور) في الحوار
- اجعل كل شخصية تتحدث بأسلوبها المميز حسب خلفيتها
- أضف تفاعلات طبيعية: <happy>, <surprise>, <overlap> (فقط عند الضرورة)
- استخدم 70% فصحى و 30% لمسات خليجية خفيفة
- أدرج مراجع ثقافية مرتبطة بالموضوع عند الحاجة
- اجعل الحوار يتكيف مع الموضوع
- أضف فواصل طبيعية [pause: 2s] عند الحاجة للتأمل
- ابدأ كل جملة بـ المقدم: أو الضيف:
- اجعل الحوار متماشياً مع الأسلوب المطلوب مع الحفاظ على التلقائية
"""
        
        response = self.deployment.chat.completions.create(
            model=self.model,
            messages=[
                {"role": "system", "content": "أنت خبير في كتابة الحوارات التلقائية والطبيعية للبودكاست العربي. تخصصك في الأسلوب التعليمي الممتع."},
                {"role": "user", "content": prompt}
            ],
            temperature=0.8
        )
        return response.choices[0].message.content

# %%
def generate_msa_podcast_script(outline_text, host_persona, guest_persona, complexity="بسيط", style="تعليمي", deployment=None):
    """
    Generate complete MSA podcast script from outline
    
    Args:
        outline_text: JSON string of the podcast outline
        host_persona: Host persona description
        guest_persona: Guest persona description  
        complexity: بسيط/متوسط/معقد (simple/medium/complex)
        style: حواري/تعليمي/ترفيهي/تحليلي (conversational/educational/entertaining/analytical)
        deployment: OpenAI client deployment
    
    Returns:
        List of dictionaries with section dialogues
    """
    
    dialogue_generator = MSASpontaneousDialogueGenerator(deployment, "gpt-4o")
    enhancer = MSADialogueEnhancer(deployment, "gpt-4o")
    
    outline = json.loads(outline_text)
    
    # Extract topic from outline for context
    episode_topic = outline.get("episode_topic", "الموضوع المطروح")
    
    # Complete Arabic dialogue style examples
    arabic_dialogue_styles = {
        "حواري": {
            "host_example": "أحمد: يا أهلاً نور! كيف الحال؟ اممم... قوليلي، شو اللي خلاكِ تدخلي هذا المجال؟ <happy>",
            "guest_example": "نور: أهلاً أحمد! الله يعطيك العافية... يعني بصراحة، هاي قصة طويلة شوي [pause: 2s] بس باختصار، كنت أشوف المشاكل حولي وأقول: ليش ما نحلها بالتقنية؟"
        },
        "تعليمي": {
            "host_example": "أحمد: اممم... نور، ممكن تشرحي لنا بطريقة بسيطة، يعني شلون تشتغل هاي التقنية؟ <happy>",
            "guest_example": "نور: طبعاً أحمد! يعني... اههه كيف أشرح [pause: 2s] تخيل إنك عندك نظام ذكي جداً، بس هذا النظام مش إنسان، هو كمبيوتر! واو صح؟"
        },
        "ترفيهي": {
            "host_example": "أحمد: هاي نور! <happy> قوليلي، إيش أغرب موقف صار معكِ في الشغل؟ يعني شي يضحك؟",
            "guest_example": "نور: ههههه واو أحمد! بصراحة مواقف كثيرة... اممم مرة كنت أجرب البرنامج وفجأة [pause: 2s] خلاص ما عاد يشتغل! قعدت أصرخ: وين راح كودي؟! <surprise>"
        },
        "تحليلي": {
            "host_example": "أحمد: نور، بناءً على الإحصائيات الحديثة، وش رايكِ في التحديات الرئيسية اللي تواجه هذا المجال؟",
            "guest_example": "نور: سؤال ممتاز أحمد... يعني إذا نتكلم بشكل تحليلي، عندنا ثلاث تحديات أساسية [pause: 2s] أولها التقنية، ثانيها التمويل، وثالثها... اممم التقبل المجتمعي"
        }
    }
    
    # Get style examples based on the selected style
    style_examples = arabic_dialogue_styles.get(style, arabic_dialogue_styles['تعليمي'])
    podcast_dialogues = []
    
    # Process conversation flow sections
    conversation_flow = outline.get("conversation_flow", {})
    
    # Intro1
    if "intro1" in conversation_flow:
        intro1_content = conversation_flow["intro1"]
        content_text = " ".join([
            intro1_content.get("opening_line", ""),
            intro1_content.get("podcast_introduction", ""),
            intro1_content.get("episode_hook", "")
        ])
        
        enhanced_intro1 = enhancer.enhance_section(
            "المقدمة الأولى",
            content_text,
            criteria="جذاب، حماسي، ترحيبي، ومتحمس",
            complexity=complexity,
            episode_topic=episode_topic,
            style_example=style_examples["host_example"]
        )
        podcast_dialogues.append({"section": "intro1", "dialogue": enhanced_intro1})
    
    # Intro2  
    if "intro2" in conversation_flow:
        intro2_content = conversation_flow["intro2"]
        content_text = " ".join([
            intro2_content.get("topic_introduction", ""),
            intro2_content.get("guest_welcome", ""),
            intro2_content.get("guest_bio_highlight", "")
        ])
        
        enhanced_intro2 = dialogue_generator.generate_dialogue(
            "تقديم الموضوع والضيف",
            content_text,
            host_persona,
            guest_persona,
            complexity=complexity,
            style=style,
            episode_topic=episode_topic,
            style_example=f"{style_examples['host_example']} {style_examples['guest_example']}"
        )
        podcast_dialogues.append({"section": "intro2", "dialogue": enhanced_intro2})
    
    # Main Discussion Points
    if "main_discussion" in conversation_flow:
        main_points = conversation_flow["main_discussion"]
        
        for i, point in enumerate(main_points):
            point_title = point.get("point_title", f"النقطة {i+1}")
            
            # Build content from all point elements
            content_parts = [
                point.get("personal_angle", ""),
                " ".join(point.get("spontaneous_triggers", [])),
                point.get("disagreement_points", ""),
                " ".join(point.get("cultural_references", [])),
                point.get("natural_transitions", ""),
                point.get("emotional_triggers", "")
            ]
            section_content = " ".join([part for part in content_parts if part])
            
            spontaneous_dialogue = dialogue_generator.generate_dialogue(
                point_title,
                section_content,
                host_persona,
                guest_persona,
                complexity=complexity,
                style=style,
                episode_topic=episode_topic,
                style_example=f"{style_examples['host_example']} {style_examples['guest_example']}"
            )
            
            podcast_dialogues.append({
                "section": f"main_point_{i+1}",
                "title": point_title,
                "dialogue": spontaneous_dialogue
            })
    
    # Closing sections
    closing = conversation_flow.get("closing", {})
    
    # Conclusion
    if "conclusion" in closing:
        conclusion_content = closing["conclusion"]
        content_text = " ".join([
            conclusion_content.get("main_takeaways", ""),
            conclusion_content.get("guest_final_message", ""),
            conclusion_content.get("host_closing_thoughts", "")
        ])
        
        enhanced_conclusion = dialogue_generator.generate_dialogue(
            "الخلاصة",
            content_text,
            host_persona,
            guest_persona,
            complexity=complexity,
            style=style,
            episode_topic=episode_topic,
            style_example=f"{style_examples['host_example']} {style_examples['guest_example']}"
        )
        podcast_dialogues.append({"section": "conclusion", "dialogue": enhanced_conclusion})
    
    # Outro
    if "outro" in closing:
        outro_content = closing["outro"]
        content_text = " ".join([
            outro_content.get("guest_appreciation", ""),
            outro_content.get("audience_thanks", ""),
            outro_content.get("call_to_action", ""),
            outro_content.get("next_episode_teaser", "")
        ])
        
        enhanced_outro = enhancer.enhance_section(
            "الختام",
            content_text,
            criteria="دافئ، ممتن، ملهم، ومشوق للحلقة القادمة",
            complexity=complexity,
            episode_topic=episode_topic,
            style_example=style_examples["host_example"]
        )
        podcast_dialogues.append({"section": "outro", "dialogue": enhanced_outro})
    
    return podcast_dialogues

# %%
# Usage example:

# Initialize
dialogue_generator = MSASpontaneousDialogueGenerator(deployment, "gpt-4o")
enhancer = MSADialogueEnhancer(deployment, "gpt-4o")

# Generate script with complexity level
podcast_script = generate_msa_podcast_script(
    outline_text,
    host_persona,
    guest_persona, 
    complexity="متوسط",  # بسيط، متوسط، معقد
    deployment=deployment
)

# Print results
for section in podcast_script:
    print(f"\\n=== {section['section']} ===")
    print(section['dialogue'])
# Out:
# \n=== intro1 ===
# ### المقدمة الأولى (مُعاد تطويرها)
#
# مريم: أهلاً وسهلاً في بودكاست "تعلّم المستقبل"، يا هلا ويا مرحبا بكل مستمعينا الأعزاء! معكم مريم أبو زهرة، واليوم عندنا موضوع... أقدر أقول إنه من النوع اللي يخلّي الواحد يعيد التفكير في كل شيء نعرفه عن المدرسة والتعليم. يعني، هل تخيلتوا يوم من الأيام أن ذكاء اصطناعي ممكن يغيّر الطريقة اللي نتعلّم فيها؟ مو بس تغييرات بسيطة، لا، تغييرات جذرية!
#
# مريم: بصراحة، كثير منّا لما يسمع كلمة "ذكاء اصطناعي"، أول شي يخطر في باله هو روبوتات ذكية أو أفلام الخيال العلمي، صح؟ لكن... اممم خلونا نكون واقعيين شوي، هذا المجال ما صار مجرد فكرة من الأفلام، صار جزء من حياتنا اليومية. واليوم، نتكلم عن كيف هالتقنية قاعدة تلعب دور كبير في التعليم، يعني في كيف الطلاب يتعلمون وكيف المعلمين يدرّسون.
#
# مريم: طبعاً، الذكاء الاصطناعي مو مجرد روبوتات تصحح الواجبات أو تُساعد الطلاب على فهم الدروس، الموضوع أعمق بكثير. بنسأل أسئلة مثل: هل ممكن الذكاء الاصطناعي يفهم احتياجات الطالب بشكل فردي؟ هل يقدر يساعد في تقليل الضغط على المعلمين؟ و... يمكن الأهم، هل هو فعلاً مفيد؟ أممم، أو ممكن يكون سلاح ذو حدين؟
#
# مريم: وفي هالحلقة، راح نغوص شوي في تفاصيل الموضوع، ونشوف أمثلة واقعية، ونحاول نتخيّل مستقبل المدرسة لو صار الذكاء الاصطناعي جزء لا يتجزأ منها. يعني... هل بيكون عندنا "معلم رقمي"؟ أو... أههه، مثلاً تطبيقات ذكية تدخل في أدق تفاصيل التعليم؟
#
# مريم: فشدّوا الأحزمة، وخلونا نتعمق أكثر في هذا العالم اللي بصراحة، كل ما اكتشفناه أكثر، كل ما حسّينا إنه المستقبل صار أقرب مما نتوقع. جاهزين؟ يالله، نبدأ الحلقة!
# \n=== intro2 ===
# المقدم: مريم: يا جماعة، الموضوع اليوم مثيييير جداً! يعني <excited> تخيلوا معي: كيف ممكن الذكاء الاصطناعي يغيّر طريقة التعليم اللي نعرفها تماماً؟ كيف لو صار عندنا معلمين رقميين؟ واااو، خيال صح؟ بس السؤال الأهم: هل إحنا مستعدين لهذا؟ وهل فعلاً ممكن الذكاء الاصطناعي يكون أفضل من المعلم البشري؟ [pause: 2s] معنا اليوم د. ليلى الخالدي، خبيرة مميزة في هذا المجال. د. ليلى، أول شيء، أهلاً وسهلاً فيك، وشلونك؟ <happy>
#
# الضيف: د. ليلى: أهلاً مريم، الله يسعدك. الحمد لله، بألف خير. جداً متحمسة نناقش هالموضوع معك ومع المستمعين اليوم. <calm>
#
# المقدم: مريم: ما شاء الله، وأنا بعد متحمسة! يعني شوف، لما نقول "الذكاء الاصطناعي"، الناس على طول يتخيلون روبوتات وشغلات خيالية. بس لو نرجع شوي للواقع، شلون الذكاء الاصطناعي ممكن يدخل التعليم؟ يعني كيف ممكن يقلب الطاولة على الطريقة التقليدية اللي ندرس بها؟ [pause: 2s]
#
# الضيف: د. ليلى: سؤال ممتاز يا مريم! خليني أبدأ ببسيط مثال. تخيلي إنك طالبة، وبدل ما يكون عندك معلم واحد في الفصل، عندك نظام ذكي يساعدك على التعلّم بطريقة تناسبك بالضبط. يعني لو كنتِ تحبين تتعلمي عن طريق الصور، النظام يقدم لك محتوى بصري أكثر. ولو كنتِ تحبين القراءة، يعطيك نصوص مكتوبة. هذا النظام يسمى "التعلّم التكيفي باستخدام الذكاء الاصطناعي". <calm>
#
# المقدم: مريم: واااو، لحظة لحظة، يعني بالضبط النظام يشتغل كأنه يعرفني شخصياً؟ كأنه يقول: "مريم، أنتِ مذاكرتك ضعيفة في الرياضيات، تعالي أعطيك تمارين إضافية." <surprise>
#
# الضيف: د. ليلى: تماماً، بالضبط! الذكاء الاصطناعي يعتمد على تحليل بياناتك الشخصية. مثلاً، كيف تجاوبين على الأسئلة، أي المواضيع تشدك أكثر، حتى أحياناً عدد المرات اللي تتوقفين فيها أثناء القراءة. كل هذا يساعد النظام على تقديم تجربة تعليمية مخصصة لك. <calm>
#
# المقدم: مريم: الله الله! طيب، بس هنا السؤال يجي... شلون يقدر النظام يعرف كل هالأشياء؟ يعني، هل هذا يعني إنه يراقبني؟ <curious>
#
# الضيف: د. ليلى: <laugh> هو ما يراقبك بمعنى التجسس، لا تخافي! لكنه يجمع معلومات بناءً على تفاعلك مع الأدوات التعليمية. مثلاً، إذا كنتِ تدرسين باستخدام تطبيق، النظام يسجل الطريقة اللي تدرسين بها، المدة اللي تقضيها على حل كل سؤال، وإذا كنتِ تحبين الفيديو أكثر من النصوص. كل هذه البيانات يتم تحليلها لتوفير تجربة تعلّم أفضل. وعشان أكون صريحة، هذا يعتمد على موافقتك في مشاركة بياناتك مع النظام. <calm>
#
# المقدم: مريم: أها، يعني لازم أكون موافقة على استخدام بياناتي. زين، هذا طمني شوي. بس شوف، عندي سؤال ثاني. هل الذكاء الاصطناعي ممكن يكون بدل المعلم؟ يعني في المستقبل، هل نقول للمعلمين: "شكراً، يعطيكم العافية، خلاص، ما نحتاجكم؟" <curious>
#
# الضيف: د. ليلى: <laugh> لا، لا، مستحيل يا مريم. المعلم يبقى عنصر أساسي في التعليم. الذكاء الاصطناعي مش هدفه إنه يحل محل المعلم، بل يساعده. خليني أشرح: المعلم عنده مهارات إنسانية مثل التعاطف، حل المشكلات، بناء العلاقات مع الطلاب، وهذي أشياء الذكاء الاصطناعي ما يقدر يقوم بها. لكن التقنية تقدر تخفف عن المعلم بعض الأعباء مثل تصحيح الاختبارات أو إعداد مواد تعليمية. يعني المعلم يصير عنده وقت أكثر للتركيز على بناء علاقة مع الطلاب وتحفيزهم. <calm>
#
# المقدم: مريم: <relief> أوف، هذا كلام جميل. يعني التقنية والمعلم يشتغلون مع بعض كفريق. زين، د. ليلى، خليني أسألك سؤال كذا شوي فلسفي. هل تعتقدين إن الذكاء الاصطناعي ممكن يعلمنا مهارات جديدة؟ يعني مو بس الرياضيات والعلوم، بل مهارات حياتية مثل التفكير النقدي أو الإبداع؟ <thoughtful>
#
# الضيف: د. ليلى: سؤال عميق فعلاً. الذكاء الاصطناعي قادر على دعم تطوير المهارات الحياتية بشكل كبير. مثلاً، هناك برامج تعتمد على الذكاء الاصطناعي لتعليم الطلاب كيفية التفكير النقدي من خلال تحليل البيانات. أو حتى مهارات الإبداع، مثل استخدام الذكاء الاصطناعي في تصميم مشاريع فنية أو كتابة قصص. لكن يبقى الذكاء الاصطناعي أداة، والطالب هو اللي لازم يكون عنده الرغبة والشغف لتطوير هذه المهارات. يعني التقنية تفتح الأبواب، لكن الإنسان هو اللي يقرر يدخل. <calm>
#
# المقدم: مريم: يا الله، كلام رائع! يعني باختصار، الذكاء الاصطناعي مثل "المرشد"، يساعدك ويوجهك، لكن القرار والتقدم بيدك أنت. واااو، فعلاً متحمسة أشوف كيف بيكون مستقبل التعليم. شكراً د. ليلى على هذا النقاش الجميل! الله يعطيك العافية. <happy>
#
# الضيف: د. ليلى: العفو يا مريم، الله يعافيك. وأنا جداً سعيدة بالنقاش اليوم. أتمنى إننا قدمنا صورة واضحة عن كيف ممكن الذكاء الاصطناعي يساهم في تحسين التعليم. شكراً لكم! <smile>
# \n=== main_point_1 ===
# **المقدم: مريم أبو زهرة**
# مريم: شلون يا دكتورة ليلى، خليني أسألك سؤال كذا مباشر... يعني كيف فعلياً الذكاء الاصطناعي يشتغل في التعليم؟ هل هو زي كأنه يقرأ أفكارنا؟ <happy>
#
# **الضيف: د. ليلى الخالدي**
# د. ليلى: لااا، يا مريم، الذكاء الاصطناعي مو ساحر، ولا يقرأ أفكارنا الحمد لله! <laugh> هو يعتمد على تحليل البيانات، مثل: درجاتك، المواد اللي تقضي وقت أطول فيها، حتى طريقة إجابتك. يعني الذكاء الاصطناعي يكوّن صورة عنك كـ "طالبة" ويستخدمها ليقترح عليك المحتوى اللي يناسبك.
#
# **المقدم: مريم أبو زهرة**
# مريم: يعني، زي كأن عندي مدرب شخصي يلازمني طول الوقت؟ واااو، هذا شعور رهيب! بس، يعني، ما تحسين إنه شوية مخيف؟ شلون نضمن إنه ما يتدخل في خصوصيتنا؟
#
# **الضيف: د. ليلى الخالدي**
# د. ليلى: صحيح كلامك، مريم. الخصوصية دائماً موضوع حساس. لكن التقنيات الحديثة تُصمم وفق قوانين صارمة تحافظ على البيانات الشخصية. خذي مثال الإمارات، عندهم أنظمة ذكية في التعليم تعتمد على الذكاء الاصطناعي لتخصيص الدروس، بس كله يتم وفق لوائح واضحة. <pause: 2s> وبصراحة، أنا أشوف إن "التعليم الشخصي" اللي يوفره الذكاء الاصطناعي هو فرصة نادرة لتحسين تجربة الطالب، بدون ما يهدد هويتنا التعليمية التقليدية.
#
# **المقدم: مريم أبو زهرة**
# مريم: تماماً، وأنتِ ذكرتِ نقطة مهمة. التعليم كان دائماً جزءاً من تراثنا العربي، زي الكتاتيب زمان، صح؟ يعني، هل ممكن الذكاء الاصطناعي يغيّر هذا التراث؟
#
# **الضيف: د. ليلى الخالدي**
# د. ليلى: شوفِ يا مريم، الذكاء الاصطناعي ما يهدف إلى محو التراث، بل هو وسيلة لتعزيز التعليم بطرق تناسب عصرنا الحالي. مثلاً، تخيلي كيف ممكن نستخدم الذكاء الاصطناعي لتعليم اللغة العربية بطريقة تفاعلية، أو حتى نشر قصص أدبية عربية بأسلوب جديد يجذب الطلاب. هذا يربط بين الماضي والمستقبل بشكل جميل.
#
# **المقدم: مريم أبو زهرة**
# مريم: أوكي، كلامك منطقي. بس، وش رايك في موضوع المعلمين؟ هل ممكن يحسّون إنهم مُهددين؟ أقصد، لو الذكاء الاصطناعي صار يدرّس الطلاب، وين دور المعلم؟
#
# **الضيف: د. ليلى الخالدي**
# د. ليلى: يا الله، سؤال مهم جدًا! شوفِ، أنا أؤمن إن دور المعلم ما يختفي أبداً. الذكاء الاصطناعي يساعد المعلم، يعطيه أدوات إضافية، مثل تحليل أداء الطلاب أو تقديم اقتراحات تعليمية. لكن المعلم يظل القلب النابض للعملية التعليمية، لأنه هو اللي يضيف الجانب الإنساني اللي التقنية ما تقدر توفره.
#
# **المقدم: مريم أبو زهرة**
# مريم: يا سلام، فعلاً المعلم هو الأساس. <pause: 2s> بس تخيّلت كذا... لو كنت أتعلم على يد روبوت، حسيت إنه شوية غريب، لكنه مثير بنفس الوقت!
#
# **الضيف: د. ليلى الخالدي**
# د. ليلى: <laugh> أنا أتفق معاك، الفكرة غريبة، لكنها ماشي الحال لو الروبوت يقدّم لك معلومات دقيقة ويساعدك تفهم بشكل أسرع. لكن تذكري، التقنية ما تحل محل المعلم، بل هي شريكه في التطوير.
#
# **المقدم: مريم أبو زهرة**
# مريم: خلاص، أنا مقتنعة! الذكاء الاصطناعي يبدو كأنه المستقبل اللي يمكن يعطينا فرص تعليمية رهيبة إذا عرفنا كيف نستخدمه صح. الله يعطيك العافية يا دكتورة ليلى، كلامك جميل ويفتح آفاق جديدة.
#
# **الضيف: د. ليلى الخالدي**
# د. ليلى: الله يعافيكِ يا مريم، وأنا سعيدة بالنقاش معكِ. وإن شاء الله يكون الذكاء الاصطناعي خطوة نحو تعليم أفضل للجميع.
# \n=== main_point_2 ===
# **المقدم: مريم أبو زهرة**
# أوه، دكتورة ليلى، بصراحة أنا مرة متحمسة لهذا الموضوع. يعني شلون الذكاء الاصطناعي ممكن يساعد الطلاب ذوي الإعاقة؟ <happy>
#
# **الضيف: د. ليلى الخالدي**
# طبعاً يا مريم، هذا أحد المجالات اللي أنا فعلاً أشوف إن الذكاء الاصطناعي قادر فيها على إحداث ثورة. يعني، تخيلي معي... طالب كفيف، عنده تطبيق قارئ للنصوص الذكي اللي يستخدم تقنيات التعلم العميق لتحويل النصوص إلى صوت بطريقة طبيعية جداً. مش بس إنه يقرأ النصوص، لكنه حتى يفهم السياق ويعدل طريقة القراءة بحسب محتوى النص.
#
# **المقدم: مريم أبو زهرة**
# واو! يعني، مثل كأنه عنده مساعد شخصي؟ هذا فعلاً رائع. بس شلون... يعني هل التقنية هذه متوفرة؟ أممم، ولا ممكن تكون مكلفة على المدارس؟ <thinking>
#
# **الضيف: د. ليلى الخالدي**
# صحيح، التقنية موجودة وعندنا أمثلة فعلاً مبهرة، زي تطبيقات مثل "Voice Dream Reader"، اللي صار معروف عالمياً. لكن التحدي الأكبر يكمن في توفير البنية التحتية، خصوصاً في المدارس العربية. مثل ما ذكرتِ، تقرير اليونسكو وضّح أن 42٪ من المدارس في المنطقة العربية تفتقر لأدوات التكنولوجيا الحديثة. يعني، شلون نقدر نتوقع تقدم بدون استثمار في الأساسيات؟
#
# **المقدم: مريم أبو زهرة**
# بالضبط، بالضبط. يعني أحياناً أحس إن الموضوع مثل زراعة النخل، إذا زرعت واهتميت فيه، بتشوف الثمار بعدين. بس السؤال هنا: هل الذكاء الاصطناعي ممكن يساهم في سد هذه الفجوة في التعليم، خاصة في المناطق النائية؟
#
# **الضيف: د. ليلى الخالدي**
# أكيد! شوفي، الذكاء الاصطناعي عنده القدرة على تقديم حلول مبتكرة ومخصصة. يعني، لو عندنا نظم تعليمية تعتمد على الذكاء الاصطناعي، نقدر نوفر دروس افتراضية تتكيف مع احتياجات كل طالب، حتى لو كان في قرية بعيدة عن المدينة. تخيلي مثلاً طالب في منطقة ريفية، يقدر يتعلم الرياضيات عبر تطبيق يستخدم الذكاء الاصطناعي لتقديم شرح يناسب مستواه واحتياجاته الخاصة.
#
# **المقدم: مريم أبو زهرة**
# الله! يعني أقدر أتخيل كيف ممكن يكون عندنا مستقبل فيه تعليم فعلاً عادِل للجميع. <pause: 2s> بس، دكتورة ليلى، هل ممكن تعطينا مثال واقعي صار في العالم العربي؟ عشان كده نحس إن الموضوع مش مجرد كلام؟
#
# **الضيف: د. ليلى الخالدي**
# طبعاً يا مريم، في البحرين، على سبيل المثال، كان فيه مشروع رائع يعتمد على الذكاء الاصطناعي لتعليم الطلاب ذوي الإعاقة السمعية. من خلال تطبيقات ترجمة لغة الإشارة، صاروا الطلاب يقدرون يتابعون الدروس مباشرة بدون أي حواجز. هذا نموذج حقيقي يثبت إن الاستثمار في التقنية ممكن يغير حياة الناس بشكل جذري.
#
# **المقدم: مريم أبو زهرة**
# يا الله، هذا فعلاً خبر يفرّح القلب! يعني، شلون أقول، التقنية مثل عصا سحرية إذا استخدمناها صح. لكن... هل تعتقدين إننا نحتاج لجهود جماعية أكثر لتسريع هذا التغيير في التعليم؟
#
# **الضيف: د. ليلى الخالدي**
# بالطبع يا مريم. الموضوع يحتاج تعاون بين الحكومات، القطاع الخاص، وحتى المجتمع المدني. يعني، إحنا كلنا مسؤولين عن دعم هذا التحول الرقمي في التعليم. لأنه في النهاية، التعليم هو أساس تقدم أي مجتمع.
#
# **المقدم: مريم أبو زهرة**
# واو، كلامك يلهمني! يعني أقدر أتخيل مستقبل تكون فيه التكنولوجيا مثل جسر يوصل كل طالب لحلمه. الله يعطيك العافية، دكتورة ليلى، على كل المعلومات الجميلة. شكراً شكراً!
#
# **الضيف: د. ليلى الخالدي**
# العفو يا مريم، وأنا سعيدة جداً بهذا الحوار الجميل. وإن شاء الله نكون جزء من هذا التغيير للأفضل.
#
# **المقدم: مريم أبو زهرة**
# إن شاء الله يا دكتورة، وإن شاء الله يكون ذكاءنا الاصطناعي... وااااااااااااااي، أقصد ذكاءنا الطبيعي، بعد، جزء من الحل. <laugh>
# \n=== main_point_3 ===
# ### **المقدمة إلى موضوع الحلقة: الذكاء الاصطناعي في التعليم: كيف يغيّر مستقبل التعلّم؟**
#
# ---
#
# **المقدم: مريم أبو زهرة**
# مريم: يا الله يا دكتورة ليلى، موضوعنا اليوم جداً مشوّق! الذكاء الاصطناعي يدخل عالم التعليم، بس... بصراحة، عندي شوي أسئلة تقلقني. شلون ممكن نتأكد إن التقنية هذه تفيدنا كبشر وما تضيع قيمنا وثقافتنا؟ <curious>
#
# ---
#
# **الضيف: د. ليلى الخالدي**
# د. ليلى: أولاً، مريم، واو! أنا أحب الفضول اللي عندك! وهذا سؤال صراحة أساسي لما نتكلم عن أي تقنية جديدة. شوفِ، الذكاء الاصطناعي، مثل أي أداة، فيه فوائد ضخمة، لكن... فيه تحديات لازم نتعامل معاها بعناية. يعني مثلاً... التحيز الخوارزمي، هذا من التحديات اللي تحتاج حلول مستدامة.
#
# ---
#
# **المقدم: مريم أبو زهرة**
# مريم: واو، التحيز الخوارزمي؟ يعني قصدك إن النظام ممكن يكون منحاز؟ اههه كيف أقول، تخيلي بس لو قرر الكمبيوتر فجأة إنني ما أستحق درجة معينة... بسبب خطأ في البرمجة! يا الله، أنا ممكن أقلب الدنيا وقتها. <laugh>
#
# ---
#
# **الضيف: د. ليلى الخالدي**
# د. ليلى: <laugh> تماماً! هنا يجي دورنا كباحثين ومطورين، لازم نفكر في أخلاقيات الذكاء الاصطناعي ونضمن إن الأنظمة مصممة بشكل عادل. يعني، مثلاً، هل تعلمين أن في بعض الدراسات اكتشفوا أن الذكاء الاصطناعي أحياناً يعطي نتائج منحازة إذا ما تم تدريبه على بيانات غير متوازنة؟ مثل الطلاب من خلفيات معينة، ممكن يحصلون تقييم أقل لو البيانات المستخدمة فيها انحياز ثقافي أو اجتماعي.
#
# ---
#
# **المقدم: مريم أبو زهرة**
# مريم: يا ساتر! يعني، شلون نحمي أنفسنا من هذا الشيء؟ هل يمكننا وضع قيود معينة؟ لأنه بصراحة، في ثقافتنا العربية، التعليم دائماً كان جزءاً من قيم إنسانية، مش مجرد درجات على ورقة، صح؟ كما يقول المثل "العلم نور"، فأنا أخاف الذكاء الاصطناعي يُطفئ هذا النور!
#
# ---
#
# **الضيف: د. ليلى الخالدي**
# د. ليلى: كلامك صحيح، مريم. التعليم في ثقافتنا له جانب إنساني قوي جداً، مثل العلاقة بين المعلم والطالب، أو التركيز على الأخلاق. وهنا يأتي الدور الأساسي للتقنية، إنها تكون أداة تدعم هذه القيم، مش تستبدلها. مثلاً، الذكاء الاصطناعي ممكن يساعد المعلمين على تخصيص التعلم حسب احتياجات الطلاب. يعني تخيلي طالب يحب الرياضيات لكن عنده ضعف في اللغة العربية، فيقدر النظام الذكي يصمم له خطة تعليمية متوازنة بناءً على احتياجاته الخاصة.
#
# ---
#
# **المقدم: مريم أبو زهرة**
# مريم: وااااو! يعني الذكاء الاصطناعي ممكن يكون زي المساعد الشخصي للطالب؟ شيء يشبه، خلاص، كأن عنده معلم خاص 24/7؟ بس، بصدق، كيف نضمن إن الذكاء الاصطناعي ما يتجاوز حدوده؟
#
# ---
#
# **الضيف: د. ليلى الخالدي**
# د. ليلى: هذا سؤال جوهري. شوفِ، في كثير من الدول وضعوا قوانين وأنظمة لضمان أن الذكاء الاصطناعي يبقى أداة وليس المتحكم. مثلاً، في الاتحاد الأوروبي، فيه تشريعات صارمة تتعلق باستخدام التكنولوجيا في التعليم، بحيث يكون لكل نظام إطار أخلاقي واضح. وبالنسبة لنا في العالم العربي، يمكننا العمل على بناء أنظمة ذكاء اصطناعي تعكس قيمنا وثقافتنا المحلية.
#
# ---
#
# **المقدم: مريم أبو زهرة**
# مريم: يعنييييي، أقدر أشوف كيف ممكن هذا الشيء يغير حياة الطلاب، لكن... شلون نواجه التحديات الثقافية؟ يمكن البعض يخاف إن الذكاء الاصطناعي يقلل التواصل الإنساني. يعني أنا شعرت بقليل من التوتر لما فكرت في هذا الموضوع، لأن التعليم عندنا مش بس دروس، فيه تفاعل، فيه مشاعر، فيه... اههه كيف أقول... روح.
#
# ---
#
# **الضيف: د. ليلى الخالدي**
# د. ليلى: صحيح جداً، مريم. وهذا اللي يميز التعليم في منطقتنا. لكن الذكاء الاصطناعي مش بالضرورة يقلل التواصل الإنساني، بالعكس، إذا استخدمناه بذكاء، ممكن يعزز هذا الجانب. مثلاً، في اليابان، يستخدمون روبوتات ذكية لتعليم الأطفال بطريقة مرحة وممتعة، لكن المعلم الحقيقي يكون موجود للإجابة عن الأسئلة المعقّدة.
#
# ---
#
# **المقدم: مريم أبو زهرة**
# مريم: وااااو، اليابان دائماً سابقين! يمكن هذا يكون الحل الأمثل، تقنية تدعمنا وما تلغي دورنا. طيب، دكتورة ليلى، لو عندك رسالة أخيرة للطلاب والمعلمين عن الذكاء الاصطناعي، شو تقولين؟
#
# ---
#
# **الضيف: د. ليلى الخالدي**
# د. ليلى: أقول لهم إن الذكاء الاصطناعي هو فرصة، لكنه يحتاج منا وعي وحكمة. لازم نكون جزءاً من تطويره، نحمي قيمنا وثقافتنا، ونستخدمه بأفضل طريقة تخدم التعلم وتنمي المهارات. وكما يقول المثل العربي: "التعلم في الصغر كالنقش على الحجر"، فلنقش مستقبلنا بأدوات ذكية ولكن بأيدٍ حكيمة.
#
# ---
#
# **المقدم: مريم أبو زهرة**
# مريم: الله يعطيك العافية، دكتورة ليلى! أنا جداً استمتعت وتعلمت منك اليوم. شكراً على وقتك وعلى المعلومات الرائعة.
#
# ---
#
# **الضيف: د. ليلى الخالدي**
# د. ليلى: العفو، مريم. وأنا سعيدة جداً بالنقاش معك. شكراً لاستضافتي.
#
# ---
#
# **المقدم: مريم أبو زهرة**
# مريم: أعزائي المستمعين، هذا كان حديثنا عن الذكاء الاصطناعي في التعليم. شلون ممكن يغير مستقبلنا وكيف نضمن إنه يبقى أداة تدعم قيمنا. شكراً لكم على المتابعة، ونلقاكم في الحلقة القادمة!
# \n=== conclusion ===
# المقدم: د. ليلى، بصدق يعني، حلقتنا اليوم كانت مليانة معلومات، بس خليني أسألك آخر سؤال كده. شلون تشوفين الذكاء الاصطناعي يغير مستقبل التعليم فعلاً؟ يعني، هل هو مجرد تقنية باردة ولا فيه روح ممكن تضيفها للتعلّم؟ <curious>
#
# الضيف: سؤال جميل يا مريم! شوفي، الذكاء الاصطناعي بالفعل يغير الطريقة اللي نتعلم بها، لكن التغيير هذا يعتمد على كيفية استخدامنا له. يعني، خذي مثال بسيط، التطبيقات الذكية اللي تقرأ أسلوب الطالب وتوجهه بشكل شخصي. تخيلي طالب في مدرسة بريف بعيد، ما عنده مدرس متخصص في مادة معينة. بس من خلال الذكاء الاصطناعي، ممكن يحصل على تعليم مصمم خصيصاً له، وكأن عنده أفضل مدرس في العالم! <enthusiastic>
#
# المقدم: وااااو، هذي الفكرة لحالها تخليك تتحمس! بس يعني، ما تحسين إن فيه جانب يخوف شوي؟ التقنية هذي قوية، صح؟ لكن، شلون نضمن إنها تخدم الطلاب وما تستغلهم؟ يعني الزين والشين في أي تقنية موجود، صح؟ <thoughtful>
#
# الضيف: صحيح تماماً يا مريم، التقنية بحد ذاتها أداة، زي السكين. ممكن تستخدمينه لتقطيع الطعام، أو للأسف، لشيء مؤذٍ. الذكاء الاصطناعي فرصة رائعة، بس لازم نستخدمه بحكمة. يعني، مثلاً، السياسات التعليمية لازم تراعي الخصوصية، وما يكون فيه استغلال لمعلومات الطلاب.
#
# المقدم: وهنا يجي دور الإنسان، صح؟ يعني مهما صار العلم ذكي، الإنسان هو الأساس. أنا مؤمنة إن الروح البشرية هي اللي تضيف القيمة الحقيقية للتعليم. <passionate>
#
# الضيف: تماماً! وهذا اللي دائماً أقوله لطلابي: التكنولوجيا ليست عدواً، بل فرصة. فرصة لنقل التعليم إلى مستوى جديد، لكن الإنسان هو اللي يحدد الاتجاه. يعني لو ركزنا على تطوير مهارات التفكير النقدي والإبداع في الطلاب، الذكاء الاصطناعي يصير أداة تعزز هالمهارات بدل ما تلغيها. <optimistic>
#
# المقدم: الله يعطيك العافية د. ليلى، بجد كلامك مريح. أحس بحماس إن المستقبل فيه مساحة للتوازن بين التقنية والبشرية. يعني، ما نخاف منها، بل نتعلم كيف نستفيد منها.
#
# الضيف: بالضبط يا مريم، وهذا هو التحدي الحقيقي. التعليم مش مجرد مواد يدرسها الطالب، التعليم هو تجربة، هو رحلة، والرحلة فيها أدوات كثيرة، منها الذكاء الاصطناعي.
#
# المقدم: رحلة، حلوة الكلمة! وأنا بصراحة أشوف إن ذي الحلقة كانت رحلة ممتعة بحد ذاتها. شكراً د. ليلى على وقتك وعلى الأفكار الجميلة اللي شاركتينا فيها.
#
# الضيف: شكراً لكِ يا مريم، وسعيدة جداً بالنقاش معكِ، ويا الله، بالتوفيق لكل الطلاب اللي يسمعوننا! التعليم هو مفتاح المستقبل، وأنا أثق إن الجيل الجديد بيستخدم الذكاء الاصطناعي بطريقة رائعة.
#
# المقدم: إن شاء الله، وأنا متفائلة بعد كلامك. شكراً لكل اللي تابعونا اليوم، ونلتقي في الحلقة الجاية مع موضوع جديد ومثير. مع السلامة!
#
# [خاتمة موسيقية خفيفة]
# \n=== outro ===
# مريم: أممم... بصراحة، ما أقدر أوصف لكم قد إيش كانت الحلقة اليوم مليئة بالإلهام والتفكير العميق. شكراً جزيلاً لكِ د. ليلى على مشاركتك لنا هذه الأفكار القيّمة والرؤى المبهرة عن الذكاء الاصطناعي في التعليم. يعني، فعلاً، ما كنا نتوقع إن التأثير ممكن يكون بهذا العمق، من تحسين طرق التدريس إلى تصميم تجارب تعلم شخصية لكل طالب.
#
# مريم: وطبعاً، أحب أقول شكراً من القلب لكل مستمعينا الأعزاء، أنتم دائماً تعطونا الطاقة للاستمرار وتقديم محتوى يليق فيكم. وجودكم معنا ودعمكم، هو اللي يخلي كل لحظة في هذا البودكاست تستحق الجهد.
#
# مريم: إيييه، لا تنسوا تشاركونا آراءكم وتوقعاتكم عن مستقبل التعليم مع الذكاء الاصطناعي! يعني، كيف تشوفون دور التقنية في تحسين حياتنا التعليمية؟ شاركونا في التعليقات أو حتى عبر وسائل التواصل. نحب نسمع منكم!
#
# مريم: وبالمناسبة، إذا عجبتكم الحلقة، عطونا تقييم أو شاركوها مع أصدقائكم اللي يهتمون بالتعليم أو التقنية. طبعاً، أنتم تعرفون إن نشر المعرفة مثل السراج اللي ينير الطريق للآخرين.
#
# مريم: وبالنسبة للحلقة القادمة... *وقفة قصيرة مع ابتسامة*... استعدوا لموضوع جديد ومثير! بنغوص في كيف نقدر نبني المهارات المستقبلية في عصر التكنولوجيا. يعني، في عالم يتغير بسرعة، شنو المهارات اللي فعلاً بتكون أساسية؟ وهل الذكاء الاصطناعي ممكن يساعدنا فيها؟ أهه... لا تفوتون الحلقة، ووعدنا لكم إنها تكون مليئة بالأفكار اللي تفتح آفاق جديدة!
#
# مريم: شكراً مرة ثانية، ونشوفكم قريب إن شاء الله... مع السلامة!
